# %%
import pandas as pd
import json

# %%
df = pd.read_csv("dataset.csv")
df
# Out:
#                                    question  \
# 0                암보험 가입 시 가족력은 어떤 영향을 미치나요?
# 1    암보험의 “계약 전 알릴 의무”는 구체적으로 어떤 항목을 포함하나요?
# 2              암보험의 특약 가입 시 보험료는 어떻게 달라지나요?
# 3              특정 암이 아닌 희귀암 진단 시에도 보장이 되나요?
# 4                  암보험의 가입 연령 제한은 몇 세까지인가요?
# ..                                      ...
# 245                 암보험을 상속 재산으로 포함할 수 있나요?
# 246       보험료 연체로 해지된 계약을 부활시키기 위해 필요한 조건은?
# 247       암보험의 납입 기간과 보장 기간을 다르게 설정할 수 있나요?
# 248      계약 내용 변경 시 추가로 발생할 수 있는 비용은 무엇인가요?
# 249             암보험의 보험료가 가장 낮은 연령대는 언제인가요?
#
#                                                context  \
# 0    가족력은 보험 가입 심사에서 중요한 요인으로 평가되며, 암 발생 위험도를 높게 평가...
# 1    계약 전 알릴 의무는 피보험자의 건강 상태, 기존 병력, 치료 이력, 직업 및 위험...
# 2    특약 가입 시 보험료는 선택한 특약의 보장 범위와 한도에 따라 추가로 부과됩니다. ...
# 3    희귀암은 약관에 명시된 조건에 따라 보장이 이루어지며, 특약을 통해 추가 보장을 받...
# 4    암보험의 가입 연령 제한은 보험사별로 상이하며, 일반적으로 만 60세에서 70세까지...
# ..                                                 ...
# ...

# %%
df[["question", "context", "response"]].loc[24].to_dict()
# Out:
# {'question': '암보험 가입자의 건강 상태가 변경되면 보험료가 자동으로 조정되나요?',
#  'context': '건강 상태 변경은 보험료 조정에 영향을 미치지 않으며, 가입 당시 기준이 유지됩니다. 단, 새로운 보장을 추가하거나 변경할 경우 추가 심사가 필요할 수 있습니다.',
#  'response': '건강 상태 변경은 기존 보험료에 영향을 미치지 않습니다. 보장 변경 시 추가 심사가 요구될 수 있습니다.'}

# %%
"""
{'question': '암보험 가입 시 가족력은 어떤 영향을 미치나요?',
 'context': '가족력은 보험 가입 심사에서 중요한 요인으로 평가되며, 암 발생 위험도를 높게 평가받을 수 있습니다. 가족력이 있을 경우 보험료가 할증되거나 가입 조건에 제한이 있을 수 있습니다.',
 'response': '가족력은 암 발생 위험 평가에 영향을 미쳐 보험료 할증이나 가입 제한이 발생할 수 있습니다. 정확한 고지로 계약 유지에 유리한 조건을 확보할 수 있습니다.'}
"""
